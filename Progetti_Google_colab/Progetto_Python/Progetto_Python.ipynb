# %% [markdown]
# **Nota bene**: nel progetto sono state fatte due aggiunte rispetto alle richieste. La prima riguarda la possibilità di visualizzare anche i prodotti venduti, la seconda la possibilità di svuotare il file per ricominciare da zero. Queste modifiche sono state fatte per agevolare la visualizzazione delle info presenti nel file. Se non dovessero risultare utili, vista la specifica di fare il progetto così come richiesto, attendo un vostro riscontro.

# %%
# !git clone https://github.com/Daddalo/store-management.git

# %%
import sys
import os
sys.path.append('/content/store-management')
os.chdir('/content/store-management')

# %%
from actions import *

while(True):
    command = input("\nInserisci comando: ").strip().lower()
    if command == "aiuto":
        command_help()
    elif command == "elenca":
        products()
    elif command == "aggiungi":
        insert()
    elif command == "profitti":
        profits()
    elif command == "vendita":
        sell()
    elif command == "vendite":
        sales()
    elif command == "svuota":
        reset()
    elif command == "chiudi":
        print("Bye!")
        break
    else:
        print("Errore nel comando inserito!")
        command_help()
